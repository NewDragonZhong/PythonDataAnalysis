# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig,axes = plt.subplots(4,1,figsize=(10,10))
# s = pd.Series(np.random.rand(0,10,16),index=list('abcdefghijklmnop'))
df = pd.DataFrame(np.random.rand(10,3),columns=list('abc'))
print(df)

x,y,z = df.loc[0]

df.plot(kind='bar',ax=axes[0],grid=True,colormap='Blues_r',stacked=True,yerr=)

for i in list(df.index):
    a,b,c = df.loc[i]
    plt.tetx(a,'%.2f' % a,color='white')
# Out:
#           a         b         c
# 0  0.166445  0.978747  0.929859
# 1  0.206579  0.237599  0.025771
# 2  0.564739  0.571213  0.829403
# 3  0.314997  0.316469  0.342258
# 4  0.004498  0.761244  0.564452
# 5  0.029912  0.293470  0.953311
# 6  0.067911  0.812732  0.431681
# 7  0.308954  0.158551  0.036535
# 8  0.177545  0.244351  0.327154
# 9  0.061487  0.930973  0.049937
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-1c475be74a8c> in <module>()
#      10 for i in list(df.index):
#      11     a,b,c = df.loc[i]
# ---> 12     plt.tetx(a,'%.2f' % a,color='white')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tetx'
