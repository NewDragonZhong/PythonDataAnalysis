# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.plot(np.random.rand(10))
plt.show()

# %%
# %matplotlib inline
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x,y)

# %%
# %matplotlib notebook
s = pd.Series(np.random.randn(100))
s.plot(style='k--o',figsize=(10,5))
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib qt5
df = pd.DataFrame(np.random.rand(50,2),columns=['A','B'])
df.hist(figsize=(12,5),color='g',alpha=0.8)

# plt.close()
# plt.gcf().clear()
# Out:
# Warning: Cannot change to a different GUI toolkit: qt5. Using notebook instead.
# <img src="data:image/png;base64,..." width="864">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000136F1940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013724160>]],
#       dtype=object)
